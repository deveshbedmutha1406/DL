# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/mnistdataset/creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
from sklearn.preprocessing import StandardScaler
obj = StandardScaler()
X = df.drop(['Class', 'Time'], axis=1)
Y = df['Class']

# %%
X['Amount'] = obj.fit_transform(X['Amount'].values.reshape(-1, 1))
X.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15  9.604066e-16
# std    1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00  1.380247e+00
# min   -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00 -1.137433e+02
# 25%   -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01 -6.915971e-01
# 50%    1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02 -5.433583e-02
# 75%    1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01  6.119264e-01
# max    2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01  3.480167e+01
#
#                  V6            V7            V8            V9           V10  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15  2.239053e-15
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X, Y, stratify=Y, test_size=0.3)
xtrain.shape
# Out:
# (199364, 29)

# %%
ytrain = ytrain.astype(bool)
ytest = ytest.astype(bool)

# %%
normal_train = xtrain[~ytrain]
normal_test = xtest[~ytest]
normal_train.shape
# Out:
# (199020, 29)

# %%
ytrain.value_counts()
# Out:
# False    199020
# True        344
# Name: Class, dtype: int64

# %%
fraud_train = xtrain[ytrain]
fraud_test = xtest[ytest]

# %%
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.models import Model, Sequential

# %%
class AutoEncoder(Model):
  def __init__(self, output_dim, ldim=8):
    super().__init__()
    self.encoder = Sequential([
        Dense(64, activation='relu'),
        Dropout(0.1),
        Dense(32, activation='relu'),
        Dropout(0.1),
        Dense(16, activation='relu'),
        Dropout(0.1),
        Dense(ldim, activation='relu'),
        Dropout(0.1),

    ])
    self.decoder = Sequential([
        Dense(16, activation='relu'),
        Dropout(0.1),
        Dense(32, activation='relu'),
        Dropout(0.1),
        Dense(64, activation='relu'),
        Dropout(0.1),
        Dense(output_dim, activation='relu'),
        Dropout(0.1),
    ])

  def call(self, inputs):
    en = self.encoder(inputs)
    de = self.decoder(en)
    return de

# %%
model = AutoEncoder(output_dim=normal_train.shape[1])
model.compile(loss='mse', optimizer='adam', metrics=['accuracy'])

# %%
h = model.fit(normal_train, normal_train, validation_data=(normal_test, normal_test), epochs=11)
# Out:
# Epoch 1/11
# 6220/6220 [==============================] - 51s 7ms/step - loss: 0.8877 - accuracy: 0.4410 - val_loss: 0.8076 - val_accuracy: 0.5967
# Epoch 2/11
# 6220/6220 [==============================] - 39s 6ms/step - loss: 0.8378 - accuracy: 0.5059 - val_loss: 0.7965 - val_accuracy: 0.6119
# Epoch 3/11
# 6220/6220 [==============================] - 38s 6ms/step - loss: 0.8283 - accuracy: 0.5118 - val_loss: 0.7830 - val_accuracy: 0.6173
# Epoch 4/11
# 6220/6220 [==============================] - 39s 6ms/step - loss: 0.8239 - accuracy: 0.5165 - val_loss: 0.7798 - val_accuracy: 0.6180
# Epoch 5/11
# 6220/6220 [==============================] - 38s 6ms/step - loss: 0.8208 - accuracy: 0.5184 - val_loss: 0.7735 - val_accuracy: 0.6189
# Epoch 6/11
# 6220/6220 [==============================] - 53s 8ms/step - loss: 0.8170 - accuracy: 0.5195 - val_loss: 0.7730 - val_accuracy: 0.6186
# Epoch 7/11
# ...

# %%
preds = model.predict(xtrain)
mse = np.mean(np.power(xtrain-preds, 2), axis=1)
err_df = pd.DataFrame({'recon_err': mse, 'class': ytrain})
err_df.groupby('class').describe()
# Out:
# 6231/6231 [==============================] - 13s 2ms/step
#       recon_err                                                       \
#           count       mean        std       min       25%        50%
# class
# False  199020.0   0.753869   3.197587  0.043041  0.261603   0.431772
# True      344.0  27.277810  38.513940  0.203967  4.342571  10.165102
#
#
#              75%         max
# class
# False   0.677599  449.338594
# True   27.426535  276.847095

# %%
thres = 0.753869 + 3.197587

# %%
test_preds = model.predict(xtest)
mse1 = np.mean(np.power(xtest-test_preds, 2), axis=1)
ypred = [(lambda er: 1 if er >= thres else 0)(er) for er in mse1]
# Out:
# 2671/2671 [==============================] - 6s 2ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(confusion_matrix(ytest, ypred))
# Out:
# [[83825  1470]
#  [   32   116]]

# %%
print(classification_report(ytest, ypred))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      0.98      0.99     85295
#         True       0.07      0.78      0.13       148
#
#     accuracy                           0.98     85443
#    macro avg       0.54      0.88      0.56     85443
# weighted avg       1.00      0.98      0.99     85443

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(mse, marker='o', linestyle='', markersize=3, label='mse')
plt.axhline(thres, linestyle='--', color='red')

# %%
thres = 0.753869 + 2 * 3.197587
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))
plt.plot(mse, marker='o', linestyle='', markersize=3, label='mse')
plt.axhline(thres, linestyle='--', color='red')

# %%
thres = 0.753869 + 3 * 3.197587
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 10))
plt.plot(mse1, marker='o', linestyle='', markersize=3, label='mse')
plt.axhline(thres, linestyle='--', color='red')

# %%
sub2 = normal_train[:10]
preds1 = model.predict(sub2)
f, a = plt.subplots(5,2,figsize=(20, 15))
cnt = 0
for i in range(10):
    a[i % 5, i % 2].plot(sub2.values[cnt], label='known')
    a[i % 5, i % 2].plot(preds1[cnt], label='predicted')
    a[i % 5, i % 2].set_title(f"{ytrain.values[i]}")
    cnt += 1
plt.legend()
plt.show()
# Out:
# 1/1 [==============================] - 0s 90ms/step
